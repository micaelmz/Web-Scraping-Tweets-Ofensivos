# %% [markdown]
# <h3>ROVENA: Web Scraping</h3>

# %% [markdown]
# Está é uma versão reduzida do código, para fins apenas webscraping

# %%
# !pip install snscrape

# %% [markdown]
# *é necessário dar pip install nas bibliotecas que não são automaticamente importadas pelo Google Colab, como é o caso da snscrape*

# %%
import snscrape.modules.twitter as sntwitter
import datetime as dt
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import smtplib

# %% [markdown]
# **Arquivos necessários**

# %% [markdown]
# Datasheet com as ofensas em português, separadas por classe: [Download](https://drive.google.com/file/d/1WuxMbhZHPoYBVbVmleyU_Jvv9GS5yb93/view?usp=share_link)<br>
# client_secret.json para autenticação com o Google Drive: [Download](https://github.com/ieee-ia-uefs/rovena/blob/main/client_secret.json)

# %% [markdown]
# <h2>DataManager</h2> é uma classe é responsável por lidar com o gerenciamento de dados, como o envio de emails e o upload de arquivos para a núvem do Google Sheets. Alguns metodos não utilizados foram removidos, porém a versào do código no [GitHub](https://github.com/ieee-ia-uefs/rovena) está completa.

# %%
class DataManager(object):

    def __init__(self):
        super().__init__()
        self.swear_list = pd.read_csv('swear_list-UPDATED.csv', index_col=False)  # lista de palavras ofensivas
        self.swear_list_category = self.swear_list.columns.tolist()  # categorias das palavras ofensivas
        self.my_email = "pythonmailtest.micael@gmail.com"  # email do remetente
        self.my_password = ""  # senha do email do remetente

    def authenticate_google_sheet(self):
        """
        Essa função é responsável por autenticar o google sheets.
        """
        scope = ["https://spreadsheets.google.com/feeds", 'https://www.googleapis.com/auth/spreadsheets',
                 "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]
        credentials = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
        client = gspread.authorize(credentials)
        return client

    def upload_to_google_sheet(self, tweets, csv_type=False):
        sheet_name = "Rovena-Results"
        client = self.authenticate_google_sheet()
        spreadsheet = client.open(sheet_name)  # o arquivo que será editado no google sheets
        if csv_type:
            client.import_csv(spreadsheet.id, data=tweets)
        else:
            spreadsheet.values_append(sheet_name, {'valueInputOption': 'RAW'}, {'values': tweets})

    def clear_csv(self):
        df = pd.DataFrame(columns=['Category', 'Text', 'Datetime', 'Tweet_Id',  'Username', 'Url', 'Word'])
        self.upload_to_google_sheet(tweets=df, csv_type=True)

# %% [markdown]
# <h2>TweetScraper</h2> é uma classe responsável por lidar com o scraping dos tweets.

# %%
class TweetScraper(object):

    def __init__(self):
        super().__init__()
        self.tweets_list = []  # lista de tweets
        self.tweets_df = pd.DataFrame()  # dataframe com os tweets
        self.MAX_TWEETS = -1

    def scrape_tweets(self, word, category):
        i = 0
        tweets_list = []
        today = dt.datetime.utcnow().date()
        for i, tweet in enumerate(sntwitter.TwitterSearchScraper(word).get_items()):
            tweets_list.append([str(category), str(tweet.content), str(tweet.date), str(tweet.id), str(tweet.username), str(tweet.url), str(word)])
            if i > self.MAX_TWEETS:
                break
        return tweets_list

    def clear_list(self):
        self.tweets_list = []

    def put_into_dataframe(self):
        self.tweets_df = pd.DataFrame(self.tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Url', 'Palavra'])
        return self.tweets_df

# %%
ts = TweetScraper()
dm = DataManager()

# %%
dm.swear_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355 entries, 0 to 354
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Etnia        11 non-null     object
#  1   Religião     2 non-null      object
#  2   Xenofobia    23 non-null     object
#  3   Capacitismo  57 non-null     object
#  4   Sexismo      30 non-null     object
#  5   Politica     6 non-null      object
#  6   Assedio      14 non-null     object
#  7   Homofobia    15 non-null     object
#  8   Aparencia    6 non-null      object
#  9   Outros       35 non-null     object
#  10  Calunia      25 non-null     object
#  11  Palavrão     355 non-null    object
# dtypes: object(12)
# memory usage: 33.4+ KB

# %%
dm.swear_list.head(7)
# Out:
#       Etnia    Religião  Xenofobia Capacitismo    Sexismo   Politica  \
# 0    criolo  macumbeiro   baianada    aidético   cachorra  comunista
# 1   crioulo      herege    ciganos    aidética     cadela   corrupta
# 2  denegrir         NaN    caipira    aleijado   rampeira   corrupto
# 3  denigrir         NaN  branquelo    aleijada     baleia    facista
# 4    macaca         NaN       japa  analfabeto      vadia   fascista
# 5    macaco         NaN     judiar  analfabeta       muie    nazista
# 6    mulata         NaN     gringo        anão  merdalher        NaN
#
#       Assedio Homofobia Aparencia    Outros    Calunia  Palavrão
# 0      cuzuda   baitola      feia    babaca      ladra      anus
# 1     boazuda     bicha      feio    bacura     ladrao  baba-ovo
# 2    bocetuda      bixa    feiosa  barbeiro  ladroeira   babaovo
# 3     bunduda    boiola    feioso     bebum    ladrona     bagos
# 4  chupadeira     veada    feioza     besta     ladrão     bisca
# 5        puta    veadao    feiozo   bárbaro      corna    bokete
# 6       rabão     veado       NaN    bêbado   cornagem    bokete

# %% [markdown]
# *as partes vazias do datasheet são mostradas pelo Pandas como "NaN", é necessário tratar isso*

# %%
terms = {category: [word for word in dm.swear_list[category] if pd.notnull(word)] for category in dm.swear_list.columns.tolist()}
print(terms)
# Out:
# {'Etnia': ['criolo', 'crioulo', 'denegrir', 'denigrir', 'macaca', 'macaco', 'mulata', 'mulato', 'negro', 'preto', 'jamal'], 'Religião': ['macumbeiro', 'herege'], 'Xenofobia': ['baianada', 'ciganos', 'caipira', 'branquelo', 'japa', 'judiar', 'gringo', 'roceiro', 'tupiniquim', 'turco', 'argentino', 'paraguaio', 'quirguistao', 'boludo', 'zulu', 'baiano', 'carcamano', 'paraiba', 'flango', 'polaca', 'xingling', 'chingchong', '(((eles)))'], 'Capacitismo': ['aidético', 'aidética', 'aleijado', 'aleijada', 'analfabeto', 'analfabeta', 'anão', 'anã', 'apenado', 'apenada', 'ceguinho', 'canceroso', 'debil', 'débil', 'debiloide', 'debilóide', 'deficiente', 'doida', 'doido', 'esclerosado', 'estupida', 'estúpida', 'estupidez', 'estupido', 'estúpido', 'idiota', 'idiotice', 'imbecil', 'inculto', 'leprosa', 'leproso', 'louco', 'maluco', 'maneta', 'mondronga', 'mondrongo', 'mongol', 'mongoloide', 'mongolóide', 'olhota', 'perneta', 'retardada', 'retardado', 'tuberculoso', 'alienado', 'anormal', 'debilmental', 'demente', 'desciclope', 'drogado', 'lazaro', 'leproso', 'lerdo', 'lesma', 'lezado', 'zoado', 'zoiudo'], 'Sexismo': ['cachorra', 'cadela', 'rampeira', 'baleia', 'vadia', 'muie', 'merdalher', 'mocrea', 'mocreia', 'mocréia', 'piranha', 'prostituta', 'sapatao', 'sapatão', 'tarado', 'traveco', 'vadia', 'vagabunda', 'vagabundo', 'arrombado', 'baitola', 'biba', 'bicha', 'boqueteiro', 'cadelona', 'meretriz', 'pistoleira', 'trepadeira', 'rapariga', 'incel'], 'Politica': ['comunista', 'corrupta', 'corrupto', 'facista', 'fascista', 'nazista'], 'Assedio': ['cuzuda', 'boazuda', 'bocetuda', 'bunduda', 'chupadeira', 'puta', 'rabão', 'rabuda', 'rabudona', 'rachada', 'safada', 'testuda', 'raspadinha', 'tarada'], 'Homofobia': ['baitola', 'bicha', 'bixa', 'boiola', 'veada', 'veadao', 'veado', 'viada', 'viadagem', 'viadao', 'viadão', 'viado', 'viadão', 'víado', 'arregassado'], 'Aparencia': ['feia', 'feio', 'feiosa', 'feioso', 'feioza', 'feiozo'], 'Outros': ['babaca', 'bacura', 'barbeiro', 'bebum', 'besta', 'bárbaro', 'bêbado', 'bêbedo', 'boco', 'bosta', 'bostana', 'boçal', 'burra', 'burro', 'caga', 'cagado', 'cagao', 'cagão', 'cagona', 'canalha', 'chifruda', 'chifrudo', 'chochota', 'coco', 'cocô', 'cretina', 'cretino', 'demonio', 'demônio', 'detento', 'difunto', 'egua', 'égua', 'elemento', 'encostado'], 'Calunia': ['ladra', 'ladrao', 'ladroeira', 'ladrona', 'ladrão', 'corna', 'cornagem', 'cornisse', 'corno', 'cornuda', 'cornudo', 'cornão', 'fanatico', 'fedorenta', 'fanatico', 'fanático', 'fedida', 'fedido', 'fedor', 'fedorenta', 'malandro', 'marginal', 'meliante', 'ignorante', 'pilantra'], 'Palavrão': ['anus', 'baba-ovo', 'babaovo', 'bagos', 'bisca', 'bokete', 'bokete', 'bolcat', 'boquete', 'bosseta', 'caceta', 'cacete', 'clitoris', 'clitóris', 'caralho', 'casseta', 'cassete', 'brioco', 'bronha', 'buca', 'buceta', 'bunda', 'merda', 'mija', 'mijada', 'mijado', 'mijo', 'minorias', 'moleca', 'moleque', 'naba', 'nadega', 'nádega', 'nhaca', 'nojeira', 'nojenta', 'nojento', 'nojo', 'otaria', 'otario', 'otária', 'otário', 'paca', 'palhaco', 'palhaço', 'paspalha', 'paspalhao', 'paspalho', 'imbecil', 'pinel', 'pivete', 'preso', 'puxa-saco', 'puxasaco', 'ramela', 'remela', 'ridícula', 'troucha', 'trouxa', 'troxa', 'animaldeteta', 'barril', 'babaca', 'benfiquista', 'desgracado', 'biroska', 'bobo', 'bocal', 'bosta', 'burro', 'cafona', 'cambista', 'capiroto', 'caralho', 'idiota', 'imundo', 'inascivel', 'inseto', 'invertebrado', 'jacu', 'jegue', 'jumento', 'energumeno', 'enfianocu', 'engolerola', 'escroto', 'esdruxulo', 'esporrado', 'estigalhado', 'estrume', 'estrunxado', 'estupido', 'gordoescroto', 'nerd', 'newbie', 'nhaca', 'nonsense', 'ogro', 'olhodocu', 'olhogordo', 'otario', 'palhaco', 'panaca', 'vagabundo', 'vagaranha', 'vaiamerda', 'vaisefuder', 'vaitomarnocu', 'vascaino', 'verme', 'tetuda', 'tetudo', 'tosco', 'tragado', 'troglodita', 'rusguento', 'sanguesuga', 'sujo', 'tapado', 'lico', 'limpezaanal', 'lixo', 'lombriga', 'miolodecu', 'mocorongo', 'montedemerda', 'morf ...

# %% [markdown]
# *agora tudo está em um dicionario, as keys são as classes, que possuem como valor uma lista de ofensas, todos os "NaN" foram removidos*

# %% [markdown]
# <h2>Web Scraping</h2>

# %%
ts.MAX_TWEETS = 1000

# %% [markdown]
# *caso não seja definido um número máximo de tweets para o scraping (no caso acima, 1000 **por categoria**), ele irá procurar até acabar os tweets com aquela palavra, ou seja, quase que infinitamente, nessa situação é necessário definir outra situação de parada, como por exemplo, uma data em especifico, assim iria minerar todos tweets daquele termo, somente em determinada data, o que resultaria em um eventual termino da operação.*

# %%
mined = 0

for category in terms.keys():
    for word in terms[category]:
        list_of_tweets = ts.scrape_tweets(word, category)
        dm.upload_to_google_sheet(list_of_tweets)
        mined += 1
        print(f"Termo {word} da categoria {category} foi minerado com sucesso! ({mined} / 189)")
    print(f"Todos os termos da categoria {category} foram minerados com sucesso!")
print(f"O data sheet foi atualizado com sucesso!")
# Out:
# Termo criolo da categoria Etnia foi minerado com sucesso! (1 / 57)
# Termo crioulo da categoria Etnia foi minerado com sucesso! (2 / 57)
# Termo denegrir da categoria Etnia foi minerado com sucesso! (3 / 57)
# Termo denigrir da categoria Etnia foi minerado com sucesso! (4 / 57)
# Termo macaca da categoria Etnia foi minerado com sucesso! (5 / 57)
# Termo macaco da categoria Etnia foi minerado com sucesso! (6 / 57)
# Termo mulata da categoria Etnia foi minerado com sucesso! (7 / 57)
# Termo mulato da categoria Etnia foi minerado com sucesso! (8 / 57)
# Termo negro da categoria Etnia foi minerado com sucesso! (9 / 57)
# Termo preto da categoria Etnia foi minerado com sucesso! (10 / 57)
# Termo jamal da categoria Etnia foi minerado com sucesso! (11 / 57)
# Todos os termos da categoria Etnia foram minerado com sucesso!
# Termo macumbeiro da categoria Religião foi minerado com sucesso! (12 / 57)
# Termo herege da categoria Religião foi minerado com sucesso! (13 / 57)
# Todos os termos da categoria Religião foram minerado com sucesso!
# Termo baianada da categoria Xenofobia foi minerado com sucesso! (14 / 57)
# Termo ciganos da categoria Xenofobia foi minerado com sucesso! (15 / 57)
# Termo caipira da categoria Xenofobia foi minerado com sucesso! (16 / 57)
# Termo branquelo da categoria Xenofobia foi minerado com sucesso! (17 / 57)
# Termo japa da categoria Xenofobia foi minerado com sucesso! (18 / 57)
# Termo judiar da categoria Xenofobia foi minerado com sucesso! (19 / 57)
# Termo gringo da categoria Xenofobia foi minerado com sucesso! (20 / 57)
# Termo roceiro da categoria Xenofobia foi minerado com sucesso! (21 / 57)
# Termo tupiniquim da categoria Xenofobia foi minerado com sucesso! (22 / 57)
# Termo turco da categoria Xenofobia foi minerado com sucesso! (23 / 57)
# Termo argentino da categoria Xenofobia foi minerado com sucesso! (24 / 57)
# Termo paraguaio da categoria Xenofobia foi minerado com sucesso! (25 / 57)
# Termo quirguistao da categoria Xenofobia foi minerado com sucesso! (26 / 57)
# Termo boludo da categoria Xenofobia foi minerado com sucesso! (27 / 57)
# Termo zulu da categoria Xenofobia foi minerado com sucesso! (28 / 57)
# Termo baiano da categoria Xenofobia foi minerado com sucesso! (29 / 57)
# Termo carcamano da categoria Xenofobia foi minerado com sucesso! (30 / 57)
# Termo paraiba da categoria Xenofobia foi minerado com sucesso! (31 / 57)
# Termo flango da categoria Xenofobia foi minerado com sucesso! (32 / 57)
# Termo polaca da categoria Xenofobia foi minerado com sucesso! (33 / 57)
# Termo xingling da categoria Xenofobia foi minerado com sucesso! (34 / 57)
# Termo chingchong da categoria Xenofobia foi minerado com sucesso! (35 / 57)
# Termo (((eles))) da categoria Xenofobia foi minerado com sucesso! (36 / 57)
# Todos os termos da categoria Xenofobia foram minerado com sucesso!
# Termo aidético da categoria Capacitismo foi minerado com sucesso! (37 / 57)
# Termo aidética da categoria Capacitismo foi minerado com sucesso! (38 / 57)
# Termo aleijado da categoria Capacitismo foi minerado com sucesso! (39 / 57)
# Termo aleijada da categoria Capacitismo foi minerado com sucesso! (40 / 57)
# Termo analfabeto da categoria Capacitismo foi minerado com sucesso! (41 / 57)
# Termo analfabeta da categoria Capacitismo foi minerado com sucesso! (42 / 57)
# Termo anão da categoria Capacitismo foi minerado com sucesso! (43 / 57)
# Termo anã da categoria Capacitismo foi minerado com sucesso! (44 / 57)
# Termo apenado da categoria Capacitismo foi minerado com sucesso! (45 / 57)
# Termo apenada da categoria Capacitismo foi minerado com sucesso! (46 / 57)
# Termo ceguinho da categoria Capacitismo foi minerado com sucesso! (47 / 57)
# Termo canceroso da categoria Capacitismo foi minerado com sucesso! (48 / 57)
# Termo debil da categoria Capacitismo foi minerado com sucesso! (49 / 57)
# Termo débil da categoria Capacitismo foi minerado com sucesso! (50 / 57)
# Termo debiloide da categoria Capacitismo foi minerado com sucesso! (51 / 57)
# Termo debilóide da categoria Capacitismo foi minerado com sucesso! (52 / 57)
# Termo deficiente da categoria Capacitismo foi minerado com sucesso! (53 / 57)
# Termo doida da categoria Capacitismo foi minerado com sucesso! (54 / 57)
# Termo doido da categoria Capacitismo foi minerado com sucesso! (55 / 57)
# Termo esclerosado da categoria Capacitismo foi minerado com sucesso! (56 / 57)
# Termo estupida da categoria Capacitismo foi minerado com sucesso! (57 / 57)
# Termo estúpida da categoria Capacitismo foi minerado com sucesso! (58 / 57)
# Termo estupidez da categoria Capacitismo foi minerado com sucesso! (59 / 57)
# Termo estupido da categoria Capacitismo foi minerado com sucesso! (60 / 57)
# Termo estúpido da categoria Capacitismo foi minerado com sucesso! (61 / 57)
# Termo idiota da categoria Capacitismo foi minerado com sucesso! (62 / 57)
# Termo idiotice da categoria Capacitismo foi minerado com sucesso! (63 / 57)
# Termo imbecil da categoria Capacitismo foi minerado com sucesso! (64 / 57)
# Termo inculto da categoria Capacitismo foi minerado com sucesso! (65 / 57)
# Termo leprosa da categoria Capacitismo foi minerado com sucesso! (66 / 57)
# Termo leproso da categoria Capacitismo foi minerado com sucesso! (67 / 57)
# Termo louco da categoria Capacitismo foi minerado com sucesso! (68 / 57)
# Termo maluco da categoria Capacitismo foi minerado com sucesso! (69 / 57)
# Termo maneta da categoria Capacitismo foi minerado com sucesso! (70 / 57)
# Termo mondronga da categoria Capacitismo foi minerado com sucesso! (71 / 57)
# Termo mondrongo da categoria Capacitismo foi minerado com sucesso! (72 / 57)
# Termo mongol da categoria Capacitismo foi minerado com sucesso! (73 / 57)
# Termo mongoloide da categoria Capacitismo foi minerado com sucesso! (74 / 57)
# Termo mongolóide da categoria Capacitismo foi minerado com sucesso! (75 / 57)
# Termo olhota da categoria Capacitismo foi minerado com sucesso! (76 / 57)
# Termo perneta da categoria Capacitismo foi minerado com sucesso! (77 / 57)
# Termo retardada da categoria Capacitismo foi minerado com sucesso! (78 / 57)
# Termo retardado da categoria Capacitismo foi minerado com sucesso! (79 / 57)
# Termo tuberculoso da categoria Capacitismo foi minerado com sucesso! (80 / 57)
# Termo alienado da categoria Capacitismo foi minerado com sucesso! (81 / 57)
# Termo anormal da categoria Capacitismo foi minerado com sucesso! (82 / 57)
# Termo debilmental da categoria Capacitismo foi minerado com sucesso! (83 / 57)
# Termo demente da categoria Capacitismo foi minerado com sucesso! (84 / 57)
# Termo desciclope da categoria Capacitismo foi minerado com sucesso! (85 / 57)
# Termo drogado da categoria Capacitismo foi minerado com sucesso! (86 / 57)
# Termo lazaro da categoria Capacitismo foi minerado com sucesso! (87 / 57)
# Termo leproso da categoria Capacitismo foi minerado com sucesso! (88 / 57)
# Termo lerdo da categoria Capacitismo foi minerado com sucesso! (89 / 57)
# Termo lesma da categoria Capacitismo foi minerado com sucesso! (90 / 57)
# Termo lezado da categoria Capacitismo foi minerado com sucesso! (91 / 57)
# Termo zoado da categoria Capacitismo foi minerado com sucesso! (92 / 57)
# Termo zoiudo da categoria Capacitismo foi minerado com sucesso! (93 / 57)
# Todos os termos da categoria Capacitismo foram minerado com sucesso!
# Termo cachorra da categoria Sexismo foi minerado com sucesso! (94 / 57)
# Termo cadela da categoria Sexismo foi minerado com sucesso! (95 / 57)
# Termo rampeira da categoria Sexismo foi minerado com sucesso! (96 / 57)
# Termo baleia da categoria Sexismo foi minerado com sucesso! (97 / 57)
# Termo vadia da categoria Sexismo foi minerado com sucesso! (98 / 57)
# Termo muie da categoria Sexismo foi minerado com sucesso! (99 / 57)
# Termo merdalher da categoria Sexismo foi minerado com sucesso! (100 / 57)
# Termo mocrea da categoria Sexismo foi minerado com sucesso! (101 / 57)
# Termo mocreia da categoria Sexismo foi minerado com sucesso! (102 / 57)
# Termo mocréia da categoria Sexismo foi minerado com sucesso! (103 / 57)
# Termo piranha da categoria Sexismo foi minerado com sucesso! (104 / 57)
# Termo prostituta da categoria Sexismo foi minerado com sucesso! (105 / 57)
# Termo sapatao da categoria Sexismo foi minerado com sucesso! (106 / 57)
# Termo sapatão da categoria Sexismo foi minerado com sucesso! (107 / 57)
# Termo tarado da categoria Sexismo foi minerado com sucesso! (108 / 57)
# Termo traveco da categoria Sexismo foi minerado com sucesso! (109 / 57)
# Termo vadia da categoria Sexismo foi minerado com sucesso! (110 / 57)
# Termo vagabunda da categoria Sexismo foi minerado com sucesso! (111 / 57)
# Termo vagabundo da categoria Sexismo foi minerado com sucesso! (112 / 57)
# Termo arrombado da categoria Sexismo foi minerado com sucesso! (113 / 57)
# Termo baitola da categoria Sexismo foi minerado com sucesso! (114 / 57)
# Termo biba da categoria Sexismo foi minerado com sucesso! (115 / 57)
# Termo bicha da categoria Sexismo foi minerado com sucesso! (116 / 57)
# Termo boqueteiro da categoria Sexismo foi minerado com sucesso! (117 / 57)
# Termo cadelona da categoria Sexismo foi minerado com sucesso! (118 / 57)
# Termo meretriz da categoria Sexismo foi minerado com sucesso! (119 / 57)
# Termo pistoleira da categoria Sexismo foi minerado com sucesso! (120 / 57)
# Termo trepadeira da categoria Sexismo foi minerado com sucesso! (121 / 57)
# Termo rapariga da categoria Sexismo foi minerado com sucesso! (122 / 57)
# Termo incel da categoria Sexismo foi minerado com sucesso! (123 / 57)
# Todos os termos da categoria Sexismo foram minerado com sucesso!
# Termo comunista da categoria Politica foi minerado com sucesso! (124 / 57)
# Termo corrupta da categoria Politica foi minerado com sucesso! (125 / 57)
# Termo corrupto da categoria Politica foi minerado com sucesso! (126 / 57)
# Termo facista da categoria Politica foi minerado com sucesso! (127 / 57)
# Termo fascista da categoria Politica foi minerado com sucesso! (128 / 57)
# Termo nazista da categoria Politica foi minerado com sucesso! (129 / 57)
# Todos os termos da categoria Politica foram minerado com sucesso!
# Termo cuzuda da categoria Assedio foi minerado com sucesso! (130 / 57)
# Termo boazuda da categoria Assedio foi minerado com sucesso! (131 / 57)
# Termo bocetuda da categoria Assedio foi minerado com sucesso! (132 / 57)
# Termo bunduda da categoria Assedio foi minerado com sucesso! (133 / 57)
# Termo chupadeira da categoria Assedio foi minerado com sucesso! (134 / 57)
# Termo puta da categoria Assedio foi minerado com sucesso! (135 / 57)
# Termo rabão da categoria Assedio foi minerado com sucesso! (136 / 57)
# Termo rabuda da categoria Assedio foi minerado com sucesso! (137 / 57)
# Termo rabudona da categoria Assedio foi minerado com sucesso! (138 / 57)
# Termo rachada da categoria Assedio foi minerado com sucesso! (139 / 57)
# Termo safada da categoria Assedio foi minerado com sucesso! (140 / 57)
# Termo testuda da categoria Assedio foi minerado com sucesso! (141 / 57)
# Termo raspadinha da categoria Assedio foi minerado com sucesso! (142 / 57)
# Termo tarada da categoria Assedio foi minerado com sucesso! (143 / 57)
# Todos os termos da categoria Assedio foram minerado com sucesso!
# Termo baitola da categoria Homofobia foi minerado com sucesso! (144 / 57)
# Termo bicha da categoria Homofobia foi minerado com sucesso! (145 / 57)
# Termo bixa da categoria Homofobia foi minerado com sucesso! (146 / 57)
# Termo boiola da categoria Homofobia foi minerado com sucesso! (147 / 57)
# Termo veada da categoria Homofobia foi minerado com sucesso! (148 / 57)
# Termo veadao da categoria Homofobia foi minerado com sucesso! (149 / 57)
# Termo veado da categoria Homofobia foi minerado com sucesso! (150 / 57)
# Termo viada da categoria Homofobia foi minerado com sucesso! (151 / 57)
# Termo viadagem da categoria Homofobia foi minerado com sucesso! (152 / 57)
# Termo viadao da categoria Homofobia foi minerado com sucesso! (153 / 57)
# Termo viadão da categoria Homofobia foi minerado com sucesso! (154 / 57)
# Termo viado da categoria Homofobia foi minerado com sucesso! (155 / 57)
# Termo viadão da categoria Homofobia foi minerado com sucesso! (156 / 57)
# Termo víado da categoria Homofobia foi minerado com sucesso! (157 / 57)
# Termo arregassado da categoria Homofobia foi minerado com sucesso! (158 / 57)
# Todos os termos da categoria Homofobia foram minerado com sucesso!
# Termo feia da categoria Aparencia foi minerado com sucesso! (159 / 57)
# Termo feio da categoria Aparencia foi minerado com sucesso! (160 / 57)
# Termo feiosa da categoria Aparencia foi minerado com sucesso! (161 / 57)
# Termo feioso da categoria Aparencia foi minerado com sucesso! (162 / 57)
# Termo feioza da categoria Aparencia foi minerado com sucesso! (163 / 57)
# Termo feiozo da categoria Aparencia foi minerado com sucesso! (164 / 57)
# Todos os termos da categoria Aparencia foram minerado com sucesso!
# Termo ladra da categoria Calunia foi minerado com sucesso! (165 / 57)
# Termo ladrao da categoria Calunia foi minerado com sucesso! (166 / 57)
# Termo ladroeira da categoria Calunia foi minerado com sucesso! (167 / 57)
# Termo ladrona da categoria Calunia foi minerado com sucesso! (168 / 57)
# Termo ladrão da categoria Calunia foi minerado com sucesso! (169 / 57)
# Termo corna da categoria Calunia foi minerado com sucesso! (170 / 57)
# Termo cornagem da categoria Calunia foi minerado com sucesso! (171 / 57)
# Termo cornisse da categoria Calunia foi minerado com sucesso! (172 / 57)
# Termo corno da categoria Calunia foi minerado com sucesso! (173 / 57)
# Termo cornuda da categoria Calunia foi minerado com sucesso! (174 / 57)
# Termo cornudo da categoria Calunia foi minerado com sucesso! (175 / 57)
# Termo cornão da categoria Calunia foi minerado com sucesso! (176 / 57)
# Termo fanatico da categoria Calunia foi minerado com sucesso! (177 / 57)
# Termo fedorenta da categoria Calunia foi minerado com sucesso! (178 / 57)
# Termo fanatico da categoria Calunia foi minerado com sucesso! (179 / 57)
# Termo fanático da categoria Calunia foi minerado com sucesso! (180 / 57)
# Termo fedida da categoria Calunia foi minerado com sucesso! (181 / 57)
# Termo fedido da categoria Calunia foi minerado com sucesso! (182 / 57)
# Termo fedor da categoria Calunia foi minerado com sucesso! (183 / 57)
# Termo fedorenta da categoria Calunia foi minerado com sucesso! (184 / 57)
# Termo malandro da categoria Calunia foi minerado com sucesso! (185 / 57)
# Termo marginal da categoria Calunia foi minerado com sucesso! (186 / 57)
# Termo meliante da categoria Calunia foi minerado com sucesso! (187 / 57)
# Termo ignorante da categoria Calunia foi minerado com sucesso! (188 / 57)
# Todos os termos da categoria Calunia foram minerado com sucesso!
# Termo pilantra da categoria Unnamed: 10 foi minerado com sucesso! (189 / 57)
# Todos os termos da categoria Unnamed: 10 foram minerado com sucesso!
# O data sheet foi atualizado com sucesso!

# %% [markdown]
# *no webscraping acima, eu removi as classes "outros" e "ofensa" por estarem muito bagunçadas, deixei somente os termos mais espeficicos*

# %%
import pandas as pd
import numpy as np

# Open a TSV file
df = pd.read_table('tsvfile.tsv')

df.head(5)
# Out:
#       Category                                               Text  \
# 0  Capacitismo              @gnfbootie29 @tommyinnit @youtube_bad
# 1        Etnia  Eu fico impressionado que a molecada da base d...
# 2      Sexismo  @Cardoso Sem prostituta e homossexualidade par...
# 3      Sexismo                                   oi eu tenho muie
# 4    Homofobia  Vontade de rebola minha bunda acho q só veado dms
#
#    Classification
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Replace all semicolons (;) in the Text column with an empty string ('')
df['Text'] = df['Text'].str.replace(',', '')

# %%
df.head(5)
# Out:
#       Category                                               Text  \
# 0  Capacitismo              @gnfbootie29 @tommyinnit @youtube_bad
# 1        Etnia  Eu fico impressionado que a molecada da base d...
# 2      Sexismo  @Cardoso Sem prostituta e homossexualidade par...
# 3      Sexismo                                   oi eu tenho muie
# 4    Homofobia  Vontade de rebola minha bunda acho q só veado dms
#
#    Classification
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# split the dataframe into groups of 5000 rows
groups = df.groupby(np.arange(len(df))//5000)

# save each group as a separate CSV file
for i, group in groups:
    group.to_csv("{}.csv".format(i))

# %%
df.head(3)
# Out:
#       Category                                               Text Offensive  \
# 0  Capacitismo              @gnfbootie29 @tommyinnit @youtube_bad
# 1        Etnia  Eu fico impressionado que a molecada da base d...
# 2      Sexismo  @Cardoso Sem prostituta e homossexualidade par...
#
#   classification
# 0           None
# 1           None
# 2           None

# %%
# create the target folder
# !mkdir target_folder

# copy files to the target folder
for i in range(60):
    # !cp {i}.csv drive/MyDrive/finalmente_ultimo/{i}.csv
# Out:
# cp: cannot stat '38.csv': No such file or directory
# cp: cannot stat '39.csv': No such file or directory
# cp: cannot stat '40.csv': No such file or directory
# cp: cannot stat '41.csv': No such file or directory
# cp: cannot stat '42.csv': No such file or directory
# cp: cannot stat '43.csv': No such file or directory
# cp: cannot stat '44.csv': No such file or directory
# cp: cannot stat '45.csv': No such file or directory
# cp: cannot stat '46.csv': No such file or directory
# cp: cannot stat '47.csv': No such file or directory
# cp: cannot stat '48.csv': No such file or directory
# cp: cannot stat '49.csv': No such file or directory
# cp: cannot stat '50.csv': No such file or directory
# cp: cannot stat '51.csv': No such file or directory
# cp: cannot stat '52.csv': No such file or directory
# cp: cannot stat '53.csv': No such file or directory
# cp: cannot stat '54.csv': No such file or directory
# cp: cannot stat '55.csv': No such file or directory
# cp: cannot stat '56.csv': No such file or directory
# cp: cannot stat '57.csv': No such file or directory
# cp: cannot stat '58.csv': No such file or directory
# cp: cannot stat '59.csv': No such file or directory
